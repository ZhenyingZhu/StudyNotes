# %% [markdown]
# ### Introduction

# %%
1+2
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/zhenyzhu/.local/bin/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'
